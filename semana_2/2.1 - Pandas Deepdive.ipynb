# %% [markdown]
# # 2.1 - Pandas Deepdive

# %% [markdown]
# ### Importar un archivo

# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_excel('../data/Online Retail.xlsx')

df.head()
# Out:
#    InvoiceNo         InvoiceDate StockCode  \
# 0     536365 2010-12-01 08:26:00    85123A
# 1     536373 2010-12-01 09:02:00    85123A
# 2     536375 2010-12-01 09:32:00    85123A
# 3     536390 2010-12-01 10:19:00    85123A
# 4     536394 2010-12-01 10:39:00    85123A
#
#                           Description  Quantity  UnitPrice  Revenue  \
# 0  CREAM HANGING HEART T-LIGHT HOLDER         6       2.55     15.3
# 1  CREAM HANGING HEART T-LIGHT HOLDER         6       2.55     15.3
# 2  CREAM HANGING HEART T-LIGHT HOLDER         6       2.55     15.3
# 3  CREAM HANGING HEART T-LIGHT HOLDER        64       2.55    163.2
# 4  CREAM HANGING HEART T-LIGHT HOLDER        32       2.55     81.6
#
#    CustomerID         Country
# 0       17850  United Kingdom
# 1       17850  United Kingdom
# 2       17850  United Kingdom
# 3       17511  United Kingdom
# 4       13408  United Kingdom

# %%
# creación de columna con nulos

df['NullID']=[i if i%2 else None for i in range(len(df))]

df.head()
# Out:
#    InvoiceNo         InvoiceDate StockCode  \
# 0     536365 2010-12-01 08:26:00    85123A
# 1     536373 2010-12-01 09:02:00    85123A
# 2     536375 2010-12-01 09:32:00    85123A
# 3     536390 2010-12-01 10:19:00    85123A
# 4     536394 2010-12-01 10:39:00    85123A
#
#                           Description  Quantity  UnitPrice  Revenue  \
# 0  CREAM HANGING HEART T-LIGHT HOLDER         6       2.55     15.3
# 1  CREAM HANGING HEART T-LIGHT HOLDER         6       2.55     15.3
# 2  CREAM HANGING HEART T-LIGHT HOLDER         6       2.55     15.3
# 3  CREAM HANGING HEART T-LIGHT HOLDER        64       2.55    163.2
# 4  CREAM HANGING HEART T-LIGHT HOLDER        32       2.55     81.6
#
#    CustomerID         Country  NullID
# 0       17850  United Kingdom     NaN
# 1       17850  United Kingdom     1.0
# 2       17850  United Kingdom     NaN
# 3       17511  United Kingdom     3.0
# 4       13408  United Kingdom     NaN

# %%
# renombrar columnas

df.columns
# Out:
# Index(['InvoiceNo', 'InvoiceDate', 'StockCode', 'Description', 'Quantity',
#        'UnitPrice', 'Revenue', 'CustomerID', 'Country', 'NullID'],
#       dtype='object')

# %%
nuevas_cols=[c.lower() for c in df.columns]

nuevas_cols
# Out:
# ['invoiceno',
#  'invoicedate',
#  'stockcode',
#  'description',
#  'quantity',
#  'unitprice',
#  'revenue',
#  'customerid',
#  'country',
#  'nullid']

# %%
df=df.rename(columns={k:v for k,v in zip(df.columns, nuevas_cols)})  # k=viejas cols, v=nuevas cols

df.head()
# Out:
#    invoiceno         invoicedate stockcode  \
# 0     536365 2010-12-01 08:26:00    85123A
# 1     536373 2010-12-01 09:02:00    85123A
# 2     536375 2010-12-01 09:32:00    85123A
# 3     536390 2010-12-01 10:19:00    85123A
# 4     536394 2010-12-01 10:39:00    85123A
#
#                           description  quantity  unitprice  revenue  \
# 0  CREAM HANGING HEART T-LIGHT HOLDER         6       2.55     15.3
# 1  CREAM HANGING HEART T-LIGHT HOLDER         6       2.55     15.3
# 2  CREAM HANGING HEART T-LIGHT HOLDER         6       2.55     15.3
# 3  CREAM HANGING HEART T-LIGHT HOLDER        64       2.55    163.2
# 4  CREAM HANGING HEART T-LIGHT HOLDER        32       2.55     81.6
#
#    customerid         country  nullid
# 0       17850  United Kingdom     NaN
# 1       17850  United Kingdom     1.0
# 2       17850  United Kingdom     NaN
# 3       17511  United Kingdom     3.0
# 4       13408  United Kingdom     NaN

# %% [markdown]
# ### Descripción de los datos

# %%
df.shape
# Out:
# (396034, 10)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 396034 entries, 0 to 396033
# Data columns (total 10 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   invoiceno    396034 non-null  int64
#  1   invoicedate  396034 non-null  datetime64[ns]
#  2   stockcode    396034 non-null  object
#  3   description  396034 non-null  object
#  4   quantity     396034 non-null  int64
#  5   unitprice    396034 non-null  float64
#  6   revenue      396034 non-null  float64
#  7   customerid   396034 non-null  int64
#  8   country      396034 non-null  object
#  9   nullid       198017 non-null  float64
# dtypes: datetime64[ns](1), float64(3), int64(3), object(3)
# memory usage: 30.2+ MB

# %%
df.info(memory_usage='deep')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 396034 entries, 0 to 396033
# Data columns (total 10 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   invoiceno    396034 non-null  int64
#  1   invoicedate  396034 non-null  datetime64[ns]
#  2   stockcode    396034 non-null  object
#  3   description  396034 non-null  object
#  4   quantity     396034 non-null  int64
#  5   unitprice    396034 non-null  float64
#  6   revenue      396034 non-null  float64
#  7   customerid   396034 non-null  int64
#  8   country      396034 non-null  object
#  9   nullid       198017 non-null  float64
# dtypes: datetime64[ns](1), float64(3), int64(3), object(3)
# memory usage: 93.7 MB

# %%
df.count()  # valores no nulos
# Out:
# invoiceno      396034
# invoicedate    396034
# stockcode      396034
# description    396034
# quantity       396034
# unitprice      396034
# revenue        396034
# customerid     396034
# country        396034
# nullid         198017
# dtype: int64

# %%
df.country.value_counts() # cuenta valores unicos en una columna
# Out:
# United Kingdom          353983
# Germany                   8658
# France                    8034
# EIRE                      7136
# Spain                     2422
# Netherlands               2322
# Belgium                   1935
# Switzerland               1810
# Portugal                  1425
# Australia                 1181
# Norway                    1048
# Channel Islands            744
# Italy                      741
# Finland                    647
# Cyprus                     612
# Sweden                     428
# Austria                    384
# Denmark                    367
# Poland                     325
# Japan                      321
# Israel                     248
# Singapore                  215
# Iceland                    182
# USA                        179
# Canada                     150
# Greece                     142
# Malta                      109
# United Arab Emirates        67
# South Africa                57
# Lebanon                     45
# ...

# %%
df['country'].unique()  # valores unicos sin cuenta
# Out:
# array(['United Kingdom', 'Spain', 'Cyprus', 'EIRE', 'Portugal',
#        'Netherlands', 'Australia', 'Singapore', 'Switzerland', 'Finland',
#        'Channel Islands', 'France', 'Malta', 'Italy', 'Israel', 'Germany',
#        'Austria', 'Norway', 'Denmark', 'Sweden', 'Belgium', 'Canada',
#        'Poland', 'Japan', 'Iceland', 'Greece', 'Lebanon', 'South Africa',
#        'Czech Republic', 'USA', 'Brazil', 'United Arab Emirates',
#        'Lithuania', 'Saudi Arabia', 'Bahrain'], dtype=object)

# %%
# descripcion estadistica del dataframe

df.describe()
# Out:
#            invoiceno       quantity      unitprice        revenue  \
# count  396034.000000  396034.000000  396034.000000  396034.000000
# mean   560620.294401      12.624838       2.867826      21.492062
# std     13110.655964      42.816911       4.265226      93.863439
# min    536365.000000       1.000000       0.040000       0.060000
# 25%    549198.500000       2.000000       1.250000       4.680000
# 50%    561894.000000       6.000000       1.950000      11.800000
# 75%    572095.000000      12.000000       3.750000      19.800000
# max    581587.000000    4800.000000     649.500000   38970.000000
#
#           customerid         nullid
# count  396034.000000  198017.000000
# mean    15302.695435  198017.000000
# std      1709.744925  114325.456929
# min     12347.000000       1.000000
# 25%     13975.000000   99009.000000
# 50%     15160.000000  198017.000000
# 75%     16805.000000  297025.000000
# max     18287.000000  396033.000000

# %%
df.describe().T
# Out:
#                count           mean            std        min        25%  \
# invoiceno   396034.0  560620.294401   13110.655964  536365.00  549198.50
# quantity    396034.0      12.624838      42.816911       1.00       2.00
# unitprice   396034.0       2.867826       4.265226       0.04       1.25
# revenue     396034.0      21.492062      93.863439       0.06       4.68
# customerid  396034.0   15302.695435    1709.744925   12347.00   13975.00
# nullid      198017.0  198017.000000  114325.456929       1.00   99009.00
#
#                   50%        75%       max
# invoiceno   561894.00  572095.00  581587.0
# quantity         6.00      12.00    4800.0
# unitprice        1.95       3.75     649.5
# revenue         11.80      19.80   38970.0
# customerid   15160.00   16805.00   18287.0
# nullid      198017.00  297025.00  396033.0

# %%
df.describe().T['50%']   # mediana de todas las columnas numericas
# Out:
# invoiceno     561894.00
# quantity           6.00
# unitprice          1.95
# revenue           11.80
# customerid     15160.00
# nullid        198017.00
# Name: 50%, dtype: float64

# %% [markdown]
# ### Selección dentro del dataframe

# %%
df[['quantity', 'unitprice']].head()  # seleccion de columnas por su nombre
# Out:
#    quantity  unitprice
# 0         6       2.55
# 1         6       2.55
# 2         6       2.55
# 3        64       2.55
# 4        32       2.55

# %%
df[df.quantity==6].head()   # seleccion con condicion, cantidad=6
# Out:
#    invoiceno         invoicedate stockcode  \
# 0     536365 2010-12-01 08:26:00    85123A
# 1     536373 2010-12-01 09:02:00    85123A
# 2     536375 2010-12-01 09:32:00    85123A
# 5     536396 2010-12-01 10:51:00    85123A
# 8     536502 2010-12-01 12:36:00    85123A
#
#                           description  quantity  unitprice  revenue  \
# 0  CREAM HANGING HEART T-LIGHT HOLDER         6       2.55     15.3
# 1  CREAM HANGING HEART T-LIGHT HOLDER         6       2.55     15.3
# 2  CREAM HANGING HEART T-LIGHT HOLDER         6       2.55     15.3
# 5  CREAM HANGING HEART T-LIGHT HOLDER         6       2.55     15.3
# 8  CREAM HANGING HEART T-LIGHT HOLDER         6       2.95     17.7
#
#    customerid         country  nullid
# 0       17850  United Kingdom     NaN
# 1       17850  United Kingdom     1.0
# 2       17850  United Kingdom     NaN
# 5       17850  United Kingdom     5.0
# 8       16552  United Kingdom     NaN

# %%
df[(df.quantity==6) & (df.unitprice==2.55)].head()   # multicondicion, & and logico
# Out:
#     invoiceno         invoicedate stockcode  \
# 0      536365 2010-12-01 08:26:00    85123A
# 1      536373 2010-12-01 09:02:00    85123A
# 2      536375 2010-12-01 09:32:00    85123A
# 5      536396 2010-12-01 10:51:00    85123A
# 15     536600 2010-12-02 08:32:00    85123A
#
#                            description  quantity  unitprice  revenue  \
# 0   CREAM HANGING HEART T-LIGHT HOLDER         6       2.55     15.3
# 1   CREAM HANGING HEART T-LIGHT HOLDER         6       2.55     15.3
# 2   CREAM HANGING HEART T-LIGHT HOLDER         6       2.55     15.3
# 5   CREAM HANGING HEART T-LIGHT HOLDER         6       2.55     15.3
# 15  CREAM HANGING HEART T-LIGHT HOLDER         6       2.55     15.3
#
#     customerid         country  nullid
# 0        17850  United Kingdom     NaN
# 1        17850  United Kingdom     1.0
# 2        17850  United Kingdom     NaN
# 5        17850  United Kingdom     5.0
# 15       17850  United Kingdom    15.0

# %%
df[(df.quantity==6) & ~(df.unitprice==2.55)].head() # ~virgulilla, no logico, lo contrario, cantidad=6, precio diferente de 2.55
# Out:
#     invoiceno         invoicedate stockcode  \
# 8      536502 2010-12-01 12:36:00    85123A
# 13     536590 2010-12-01 16:52:00    85123A
# 14     536594 2010-12-01 17:22:00    85123A
# 17     536607 2010-12-02 09:29:00    85123A
# 32     536833 2010-12-02 17:48:00    85123A
#
#                            description  quantity  unitprice  revenue  \
# 8   CREAM HANGING HEART T-LIGHT HOLDER         6       2.95     17.7
# 13  CREAM HANGING HEART T-LIGHT HOLDER         6       2.95     17.7
# 14  CREAM HANGING HEART T-LIGHT HOLDER         6       2.95     17.7
# 17  CREAM HANGING HEART T-LIGHT HOLDER         6       2.95     17.7
# 32  CREAM HANGING HEART T-LIGHT HOLDER         6       2.95     17.7
#
#     customerid         country  nullid
# 8        16552  United Kingdom     NaN
# 13       13065  United Kingdom    13.0
# 14       15235  United Kingdom     NaN
# 17       17732  United Kingdom    17.0
# 32       18239  United Kingdom     NaN

# %%
df[(df.quantity==6) & (df.unitprice!=2.55)].head()
# Out:
#     invoiceno         invoicedate stockcode  \
# 8      536502 2010-12-01 12:36:00    85123A
# 13     536590 2010-12-01 16:52:00    85123A
# 14     536594 2010-12-01 17:22:00    85123A
# 17     536607 2010-12-02 09:29:00    85123A
# 32     536833 2010-12-02 17:48:00    85123A
#
#                            description  quantity  unitprice  revenue  \
# 8   CREAM HANGING HEART T-LIGHT HOLDER         6       2.95     17.7
# 13  CREAM HANGING HEART T-LIGHT HOLDER         6       2.95     17.7
# 14  CREAM HANGING HEART T-LIGHT HOLDER         6       2.95     17.7
# 17  CREAM HANGING HEART T-LIGHT HOLDER         6       2.95     17.7
# 32  CREAM HANGING HEART T-LIGHT HOLDER         6       2.95     17.7
#
#     customerid         country  nullid
# 8        16552  United Kingdom     NaN
# 13       13065  United Kingdom    13.0
# 14       15235  United Kingdom     NaN
# 17       17732  United Kingdom    17.0
# 32       18239  United Kingdom     NaN

# %%
df[(df.quantity==6) | (df.country=='EIRE')].tail()  # | or logico
# Out:
#         invoiceno                invoicedate stockcode  \
# 396015     580318 2011-12-02 15:38:59.999999     23561
# 396016     580542 2011-12-05 09:04:00.000000     23561
# 396017     580544 2011-12-05 09:14:59.999999     23561
# 396019     581021 2011-12-07 10:23:59.999999     23561
# 396023     581581 2011-12-09 12:20:00.000000     23561
#
#                    description  quantity  unitprice  revenue  customerid  \
# 396015  SET OF 6 RIBBONS PARTY         6       2.89    17.34       17686
# 396016  SET OF 6 RIBBONS PARTY         6       2.89    17.34       15358
# 396017  SET OF 6 RIBBONS PARTY         6       2.89    17.34       15156
# 396019  SET OF 6 RIBBONS PARTY         6       2.89    17.34       14769
# 396023  SET OF 6 RIBBONS PARTY         6       2.89    17.34       17581
#
#                country    nullid
# 396015  United Kingdom  396015.0
# 396016  United Kingdom       NaN
# 396017  United Kingdom  396017.0
# 396019  United Kingdom  396019.0
# ...

# %%
df.iloc[0]   # seleccion por indice, primera fila
# Out:
# invoiceno                                  536365
# invoicedate                   2010-12-01 08:26:00
# stockcode                                  85123A
# description    CREAM HANGING HEART T-LIGHT HOLDER
# quantity                                        6
# unitprice                                    2.55
# revenue                                      15.3
# customerid                                  17850
# country                            United Kingdom
# nullid                                        NaN
# Name: 0, dtype: object

# %%
df.iloc[0:2]
# Out:
#    invoiceno         invoicedate stockcode  \
# 0     536365 2010-12-01 08:26:00    85123A
# 1     536373 2010-12-01 09:02:00    85123A
#
#                           description  quantity  unitprice  revenue  \
# 0  CREAM HANGING HEART T-LIGHT HOLDER         6       2.55     15.3
# 1  CREAM HANGING HEART T-LIGHT HOLDER         6       2.55     15.3
#
#    customerid         country  nullid
# 0       17850  United Kingdom     NaN
# 1       17850  United Kingdom     1.0

# %%
df.iloc[:2, 1:4]   # df.iloc[fila_ini:fila_final, col_inicial:col_final] por indice
# Out:
#           invoicedate stockcode                         description
# 0 2010-12-01 08:26:00    85123A  CREAM HANGING HEART T-LIGHT HOLDER
# 1 2010-12-01 09:02:00    85123A  CREAM HANGING HEART T-LIGHT HOLDER

# %%
df.loc[0:3]  # localiza por elemento
# Out:
#    invoiceno         invoicedate stockcode  \
# 0     536365 2010-12-01 08:26:00    85123A
# 1     536373 2010-12-01 09:02:00    85123A
# 2     536375 2010-12-01 09:32:00    85123A
# 3     536390 2010-12-01 10:19:00    85123A
#
#                           description  quantity  unitprice  revenue  \
# 0  CREAM HANGING HEART T-LIGHT HOLDER         6       2.55     15.3
# 1  CREAM HANGING HEART T-LIGHT HOLDER         6       2.55     15.3
# 2  CREAM HANGING HEART T-LIGHT HOLDER         6       2.55     15.3
# 3  CREAM HANGING HEART T-LIGHT HOLDER        64       2.55    163.2
#
#    customerid         country  nullid
# 0       17850  United Kingdom     NaN
# 1       17850  United Kingdom     1.0
# 2       17850  United Kingdom     NaN
# 3       17511  United Kingdom     3.0

# %%
df.loc[0:3, ['invoicedate', 'invoiceno']]   # df.loc[[index], [columnas]]
# Out:
#           invoicedate  invoiceno
# 0 2010-12-01 08:26:00     536365
# 1 2010-12-01 09:02:00     536373
# 2 2010-12-01 09:32:00     536375
# 3 2010-12-01 10:19:00     536390

# %%
df.sample(6)   # muestra aleatoria de 6 elementos
# Out:
#         invoiceno                invoicedate stockcode  \
# 157197     545460 2011-03-02 17:33:00.000000     22697
# 194084     537381 2010-12-06 13:13:00.000000     85038
# 385379     569359 2011-10-03 14:55:00.000000     23113
# 126044     580963 2011-12-06 14:49:00.000000     22557
# 205852     553348 2011-05-16 13:19:59.999999     22440
# 341497     568908 2011-09-29 13:38:00.000000     23170
#
#                              description  quantity  unitprice  revenue  \
# 157197   GREEN REGENCY TEACUP AND SAUCER         1       2.95     2.95
# 194084   6 CHOCOLATE LOVE HEART T-LIGHTS         6       2.10    12.60
# 385379             PANTRY CHOPPING BOARD         3       4.95    14.85
# 126044  PLASTERS IN TIN VINTAGE PAISLEY         12       1.65    19.80
# 205852     BALLOON WATER BOMB PACK OF 35        20       0.42     8.40
# 341497          REGENCY TEA PLATE ROSES         12       1.65    19.80
#
#         customerid         country    nullid
# ...

# %%
df.sample(frac=0.1).head()  # muestra aleatoria del 10%
# Out:
#         invoiceno         invoicedate stockcode  \
# 64917      580262 2011-12-02 12:42:00     21891
# 381198     575487 2011-11-09 17:11:00     23396
# 395784     578993 2011-11-27 15:38:00     23498
# 342079     575337 2011-11-09 14:11:00     23084
# 211577     538053 2010-12-09 13:34:00     20676
#
#                              description  quantity  unitprice  revenue  \
# 64917   TRADITIONAL WOODEN SKIPPING ROPE        12       1.45    17.40
# 381198           BUTTERFLY CUSHION COVER         4       3.75    15.00
# 395784            CLASSIC BICYCLE CLIPS          1       1.45     1.45
# 342079                RABBIT NIGHT LIGHT         1       2.08     2.08
# 211577                RED RETROSPOT BOWL        16       1.25    20.00
#
#         customerid         country    nullid
# 64917        16759  United Kingdom   64917.0
# 381198       15450  United Kingdom       NaN
# 395784       15987  United Kingdom       NaN
# 342079       17867  United Kingdom  342079.0
# ...

# %%
df._get_numeric_data().head()   # solo las columnas numericas
# Out:
#    invoiceno  quantity  unitprice  revenue  customerid  nullid
# 0     536365         6       2.55     15.3       17850     NaN
# 1     536373         6       2.55     15.3       17850     1.0
# 2     536375         6       2.55     15.3       17850     NaN
# 3     536390        64       2.55    163.2       17511     3.0
# 4     536394        32       2.55     81.6       13408     NaN

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 396034 entries, 0 to 396033
# Data columns (total 10 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   invoiceno    396034 non-null  int64
#  1   invoicedate  396034 non-null  datetime64[ns]
#  2   stockcode    396034 non-null  object
#  3   description  396034 non-null  object
#  4   quantity     396034 non-null  int64
#  5   unitprice    396034 non-null  float64
#  6   revenue      396034 non-null  float64
#  7   customerid   396034 non-null  int64
#  8   country      396034 non-null  object
#  9   nullid       198017 non-null  float64
# dtypes: datetime64[ns](1), float64(3), int64(3), object(3)
# memory usage: 30.2+ MB

# %%
df.select_dtypes(include=['int64']).head()
# Out:
#    invoiceno  quantity  customerid
# 0     536365         6       17850
# 1     536373         6       17850
# 2     536375         6       17850
# 3     536390        64       17511
# 4     536394        32       13408

# %%
df.select_dtypes(include=['int64', 'float64'], exclude='datetime64[ns]').head()
# Out:
#    invoiceno  quantity  unitprice  revenue  customerid  nullid
# 0     536365         6       2.55     15.3       17850     NaN
# 1     536373         6       2.55     15.3       17850     1.0
# 2     536375         6       2.55     15.3       17850     NaN
# 3     536390        64       2.55    163.2       17511     3.0
# 4     536394        32       2.55     81.6       13408     NaN

# %% [markdown]
# ### Cambio del tipo de datos

# %%
df.quantity.astype(dtype='int8')   # cambiar el tipo de dato
# Out:
# 0          6
# 1          6
# 2          6
# 3         64
# 4         32
#           ..
# 396029    12
# 396030    12
# 396031    12
# 396032    12
# 396033     1
# Name: quantity, Length: 396034, dtype: int8

# %%
#OJO, para cambiar el tipo hay que sobreescribir la columna

df.quantity=df.quantity.astype(dtype='int8')

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 396034 entries, 0 to 396033
# Data columns (total 10 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   invoiceno    396034 non-null  int64
#  1   invoicedate  396034 non-null  datetime64[ns]
#  2   stockcode    396034 non-null  object
#  3   description  396034 non-null  object
#  4   quantity     396034 non-null  int8
#  5   unitprice    396034 non-null  float64
#  6   revenue      396034 non-null  float64
#  7   customerid   396034 non-null  int64
#  8   country      396034 non-null  object
#  9   nullid       198017 non-null  float64
# dtypes: datetime64[ns](1), float64(3), int64(2), int8(1), object(3)
# memory usage: 27.6+ MB

# %% [markdown]
# ### Manejo de valores nulos

# %%
df.isna().head()   # ¿es nulo?
# Out:
#    invoiceno  invoicedate  stockcode  description  quantity  unitprice  \
# 0      False        False      False        False     False      False
# 1      False        False      False        False     False      False
# 2      False        False      False        False     False      False
# 3      False        False      False        False     False      False
# 4      False        False      False        False     False      False
#
#    revenue  customerid  country  nullid
# 0    False       False    False    True
# 1    False       False    False   False
# 2    False       False    False    True
# 3    False       False    False   False
# 4    False       False    False    True

# %%
df.notna().head()   # ¿es NO nulo?
# Out:
#    invoiceno  invoicedate  stockcode  description  quantity  unitprice  \
# 0       True         True       True         True      True       True
# 1       True         True       True         True      True       True
# 2       True         True       True         True      True       True
# 3       True         True       True         True      True       True
# 4       True         True       True         True      True       True
#
#    revenue  customerid  country  nullid
# 0     True        True     True   False
# 1     True        True     True    True
# 2     True        True     True   False
# 3     True        True     True    True
# 4     True        True     True   False

# %%
nan_cols=df.isna().sum()

nan_cols[nan_cols>0]
# Out:
# nullid    198017
# dtype: int64

# %% [markdown]
# **¿Qué hacemos?**

# %%
# podemos rellenar

df.fillna(0).head()   # rellena con un cero
# Out:
#    invoiceno         invoicedate stockcode  \
# 0     536365 2010-12-01 08:26:00    85123A
# 1     536373 2010-12-01 09:02:00    85123A
# 2     536375 2010-12-01 09:32:00    85123A
# 3     536390 2010-12-01 10:19:00    85123A
# 4     536394 2010-12-01 10:39:00    85123A
#
#                           description  quantity  unitprice  revenue  \
# 0  CREAM HANGING HEART T-LIGHT HOLDER         6       2.55     15.3
# 1  CREAM HANGING HEART T-LIGHT HOLDER         6       2.55     15.3
# 2  CREAM HANGING HEART T-LIGHT HOLDER         6       2.55     15.3
# 3  CREAM HANGING HEART T-LIGHT HOLDER        64       2.55    163.2
# 4  CREAM HANGING HEART T-LIGHT HOLDER        32       2.55     81.6
#
#    customerid         country  nullid
# 0       17850  United Kingdom     0.0
# 1       17850  United Kingdom     1.0
# 2       17850  United Kingdom     0.0
# 3       17511  United Kingdom     3.0
# 4       13408  United Kingdom     0.0

# %%
df.fillna(df.nullid.mean()).head()   # rellena con la media
# Out:
#    invoiceno         invoicedate stockcode  \
# 0     536365 2010-12-01 08:26:00    85123A
# 1     536373 2010-12-01 09:02:00    85123A
# 2     536375 2010-12-01 09:32:00    85123A
# 3     536390 2010-12-01 10:19:00    85123A
# 4     536394 2010-12-01 10:39:00    85123A
#
#                           description  quantity  unitprice  revenue  \
# 0  CREAM HANGING HEART T-LIGHT HOLDER         6       2.55     15.3
# 1  CREAM HANGING HEART T-LIGHT HOLDER         6       2.55     15.3
# 2  CREAM HANGING HEART T-LIGHT HOLDER         6       2.55     15.3
# 3  CREAM HANGING HEART T-LIGHT HOLDER        64       2.55    163.2
# 4  CREAM HANGING HEART T-LIGHT HOLDER        32       2.55     81.6
#
#    customerid         country    nullid
# 0       17850  United Kingdom  198017.0
# 1       17850  United Kingdom       1.0
# 2       17850  United Kingdom  198017.0
# 3       17511  United Kingdom       3.0
# 4       13408  United Kingdom  198017.0

# %%
df.fillna(df.nullid.median()).head()   # rellena con la mediana
# Out:
#    invoiceno         invoicedate stockcode  \
# 0     536365 2010-12-01 08:26:00    85123A
# 1     536373 2010-12-01 09:02:00    85123A
# 2     536375 2010-12-01 09:32:00    85123A
# 3     536390 2010-12-01 10:19:00    85123A
# 4     536394 2010-12-01 10:39:00    85123A
#
#                           description  quantity  unitprice  revenue  \
# 0  CREAM HANGING HEART T-LIGHT HOLDER         6       2.55     15.3
# 1  CREAM HANGING HEART T-LIGHT HOLDER         6       2.55     15.3
# 2  CREAM HANGING HEART T-LIGHT HOLDER         6       2.55     15.3
# 3  CREAM HANGING HEART T-LIGHT HOLDER        64       2.55    163.2
# 4  CREAM HANGING HEART T-LIGHT HOLDER        32       2.55     81.6
#
#    customerid         country    nullid
# 0       17850  United Kingdom  198017.0
# 1       17850  United Kingdom       1.0
# 2       17850  United Kingdom  198017.0
# 3       17511  United Kingdom       3.0
# 4       13408  United Kingdom  198017.0

# %%
# podemos borrar la columna

df.drop('nullid', axis=1).head()    # borrar una columna
# Out:
#    invoiceno         invoicedate stockcode  \
# 0     536365 2010-12-01 08:26:00    85123A
# 1     536373 2010-12-01 09:02:00    85123A
# 2     536375 2010-12-01 09:32:00    85123A
# 3     536390 2010-12-01 10:19:00    85123A
# 4     536394 2010-12-01 10:39:00    85123A
#
#                           description  quantity  unitprice  revenue  \
# 0  CREAM HANGING HEART T-LIGHT HOLDER         6       2.55     15.3
# 1  CREAM HANGING HEART T-LIGHT HOLDER         6       2.55     15.3
# 2  CREAM HANGING HEART T-LIGHT HOLDER         6       2.55     15.3
# 3  CREAM HANGING HEART T-LIGHT HOLDER        64       2.55    163.2
# 4  CREAM HANGING HEART T-LIGHT HOLDER        32       2.55     81.6
#
#    customerid         country
# 0       17850  United Kingdom
# 1       17850  United Kingdom
# 2       17850  United Kingdom
# 3       17511  United Kingdom
# 4       13408  United Kingdom

# %%
df.drop(columns=['invoicedate', 'stockcode']).head()  # eliminar varias
# Out:
#    invoiceno                         description  quantity  unitprice  \
# 0     536365  CREAM HANGING HEART T-LIGHT HOLDER         6       2.55
# 1     536373  CREAM HANGING HEART T-LIGHT HOLDER         6       2.55
# 2     536375  CREAM HANGING HEART T-LIGHT HOLDER         6       2.55
# 3     536390  CREAM HANGING HEART T-LIGHT HOLDER        64       2.55
# 4     536394  CREAM HANGING HEART T-LIGHT HOLDER        32       2.55
#
#    revenue  customerid         country  nullid
# 0     15.3       17850  United Kingdom     NaN
# 1     15.3       17850  United Kingdom     1.0
# 2     15.3       17850  United Kingdom     NaN
# 3    163.2       17511  United Kingdom     3.0
# 4     81.6       13408  United Kingdom     NaN

# %%
df.head()
# Out:
#    invoiceno         invoicedate stockcode  \
# 0     536365 2010-12-01 08:26:00    85123A
# 1     536373 2010-12-01 09:02:00    85123A
# 2     536375 2010-12-01 09:32:00    85123A
# 3     536390 2010-12-01 10:19:00    85123A
# 4     536394 2010-12-01 10:39:00    85123A
#
#                           description  quantity  unitprice  revenue  \
# 0  CREAM HANGING HEART T-LIGHT HOLDER         6       2.55     15.3
# 1  CREAM HANGING HEART T-LIGHT HOLDER         6       2.55     15.3
# 2  CREAM HANGING HEART T-LIGHT HOLDER         6       2.55     15.3
# 3  CREAM HANGING HEART T-LIGHT HOLDER        64       2.55    163.2
# 4  CREAM HANGING HEART T-LIGHT HOLDER        32       2.55     81.6
#
#    customerid         country  nullid
# 0       17850  United Kingdom     NaN
# 1       17850  United Kingdom     1.0
# 2       17850  United Kingdom     NaN
# 3       17511  United Kingdom     3.0
# 4       13408  United Kingdom     NaN

# %%
# para no sobreescribir el original, copiarlo

df_2=df.copy()

# %%
# podemos borra registros

df[df.nullid.isna()].head()   # seleccionar donde nulos en columna nullid
# Out:
#    invoiceno                invoicedate stockcode  \
# 0     536365 2010-12-01 08:26:00.000000    85123A
# 2     536375 2010-12-01 09:32:00.000000    85123A
# 4     536394 2010-12-01 10:39:00.000000    85123A
# 6     536401 2010-12-01 11:21:00.000001    85123A
# 8     536502 2010-12-01 12:36:00.000000    85123A
#
#                           description  quantity  unitprice  revenue  \
# 0  CREAM HANGING HEART T-LIGHT HOLDER         6       2.55     15.3
# 2  CREAM HANGING HEART T-LIGHT HOLDER         6       2.55     15.3
# 4  CREAM HANGING HEART T-LIGHT HOLDER        32       2.55     81.6
# 6  CREAM HANGING HEART T-LIGHT HOLDER         4       2.95     11.8
# 8  CREAM HANGING HEART T-LIGHT HOLDER         6       2.95     17.7
#
#    customerid         country  nullid
# 0       17850  United Kingdom     NaN
# 2       17850  United Kingdom     NaN
# 4       13408  United Kingdom     NaN
# 6       15862  United Kingdom     NaN
# 8       16552  United Kingdom     NaN

# %%
df.dropna().head()   # elimina nulos
# Out:
#    invoiceno         invoicedate stockcode  \
# 1     536373 2010-12-01 09:02:00    85123A
# 3     536390 2010-12-01 10:19:00    85123A
# 5     536396 2010-12-01 10:51:00    85123A
# 7     536406 2010-12-01 11:33:00    85123A
# 9     536520 2010-12-01 12:43:00    85123A
#
#                           description  quantity  unitprice  revenue  \
# 1  CREAM HANGING HEART T-LIGHT HOLDER         6       2.55    15.30
# 3  CREAM HANGING HEART T-LIGHT HOLDER        64       2.55   163.20
# 5  CREAM HANGING HEART T-LIGHT HOLDER         6       2.55    15.30
# 7  CREAM HANGING HEART T-LIGHT HOLDER         8       2.55    20.40
# 9  CREAM HANGING HEART T-LIGHT HOLDER         3       2.95     8.85
#
#    customerid         country  nullid
# 1       17850  United Kingdom     1.0
# 3       17511  United Kingdom     3.0
# 5       17850  United Kingdom     5.0
# 7       17850  United Kingdom     7.0
# 9       14729  United Kingdom     9.0

# %%
# eliminar duplicados

df.drop_duplicates().head()   # si y solo si son exactamente iguales
# Out:
#    invoiceno         invoicedate stockcode  \
# 0     536365 2010-12-01 08:26:00    85123A
# 1     536373 2010-12-01 09:02:00    85123A
# 2     536375 2010-12-01 09:32:00    85123A
# 3     536390 2010-12-01 10:19:00    85123A
# 4     536394 2010-12-01 10:39:00    85123A
#
#                           description  quantity  unitprice  revenue  \
# 0  CREAM HANGING HEART T-LIGHT HOLDER         6       2.55     15.3
# 1  CREAM HANGING HEART T-LIGHT HOLDER         6       2.55     15.3
# 2  CREAM HANGING HEART T-LIGHT HOLDER         6       2.55     15.3
# 3  CREAM HANGING HEART T-LIGHT HOLDER        64       2.55    163.2
# 4  CREAM HANGING HEART T-LIGHT HOLDER        32       2.55     81.6
#
#    customerid         country  nullid
# 0       17850  United Kingdom     NaN
# 1       17850  United Kingdom     1.0
# 2       17850  United Kingdom     NaN
# 3       17511  United Kingdom     3.0
# 4       13408  United Kingdom     NaN

# %%
df.drop_duplicates(subset=['country']).head()
# Out:
#      invoiceno                invoicedate stockcode  \
# 0       536365 2010-12-01 08:26:00.000000    85123A
# 103     538095 2010-12-09 14:55:00.000000    85123A
# 147     538826 2010-12-14 12:58:00.000000    85123A
# 179     539320 2010-12-16 19:16:00.000000    85123A
# 183     539353 2010-12-17 11:29:59.999999    85123A
#
#                             description  quantity  unitprice  revenue  \
# 0    CREAM HANGING HEART T-LIGHT HOLDER         6       2.55    15.30
# 103  CREAM HANGING HEART T-LIGHT HOLDER         1       2.95     2.95
# 147  CREAM HANGING HEART T-LIGHT HOLDER        64       2.55   163.20
# 179  CREAM HANGING HEART T-LIGHT HOLDER        24       2.95    70.80
# 183  CREAM HANGING HEART T-LIGHT HOLDER         6       2.95    17.70
#
#      customerid         country  nullid
# 0         17850  United Kingdom     NaN
# 103       17097           Spain   103.0
# 147       12370          Cyprus   147.0
# 179       14911            EIRE   179.0
# ...

# %% [markdown]
# ### Agrupación

# %%
df.groupby('country').agg('sum').head()   # para agrupar es necesaria la funcion de agragacion
# Out:
#             invoiceno  quantity  unitprice    revenue  customerid       nullid
# country
# Australia   656866967   21692.0    3262.50  138171.31    14708852  116591145.0
# Austria     216042887    3820.0    1145.90    8742.68     4808382   36538436.0
# Bahrain       9397437     260.0      78.95     548.40      210027    1300214.0
# Belgium    1084768176   22194.0    5887.85   36927.34    24054214  193310168.0
# Brazil       17606432     356.0     142.60    1143.60      408608    2712644.0

# %%
df.groupby('country').agg({'quantity': 'sum', 'revenue': 'mean', 'customerid': 'count'}).head()
# Out:
#            quantity     revenue  customerid
# country
# Australia   21692.0  116.995182        1181
# Austria      3820.0   22.767396         384
# Bahrain       260.0   32.258824          17
# Belgium     22194.0   19.083897        1935
# Brazil        356.0   35.737500          32

# %% [markdown]
# ### Pivot Table y Crosstab

# %%
df2=pd.read_csv('../data/student-por.csv', sep=';')

df2.head()
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  ...  \
# 0     GP   F   18       U     GT3       A     4     4  at_home   teacher  ...
# 1     GP   F   17       U     GT3       T     1     1  at_home     other  ...
# 2     GP   F   15       U     LE3       T     1     1  at_home     other  ...
# 3     GP   F   15       U     GT3       T     4     2   health  services  ...
# 4     GP   F   16       U     GT3       T     3     3    other     other  ...
#
#   famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 0      4        3      4     1     1      3        4   0  11  11
# 1      5        3      3     1     1      3        2   9  11  11
# 2      4        3      2     2     3      3        6  12  13  12
# 3      3        2      2     1     1      5        0  14  14  14
# 4      4        3      2     1     2      5        0  11  13  13
#
# [5 rows x 33 columns]

# %%
pd.crosstab(index=df2.sex, columns=df2.famsize)  # cruce, el count
# Out:
# famsize  GT3  LE3
# sex
# F        284   99
# M        173   93

# %%
df2.pivot_table(index=['school'],
                columns=['sex', 'studytime'],
                values=['G3'])
# Out:
#                   G3                                                         \
# sex                F                                           M
# studytime          1          2          3          4          1          2
# school
# GP         12.142857  12.904000  13.528302  14.235294  11.194805  12.469136
# MS         10.340426  10.986301  12.136364  14.000000   9.586957  10.115385
#
#
# sex
# studytime          3      4
# school
# GP         13.666667  12.00
# MS         13.250000   9.75

# %%
df2.pivot_table(index=['school'],
                columns=['sex', 'studytime'],
                values=['G3'],
                fill_value=0)   # por si tiene nan, la media por defecto
# Out:
#                   G3                                                         \
# sex                F                                           M
# studytime          1          2          3          4          1          2
# school
# GP         12.142857  12.904000  13.528302  14.235294  11.194805  12.469136
# MS         10.340426  10.986301  12.136364  14.000000   9.586957  10.115385
#
#
# sex
# studytime          3      4
# school
# GP         13.666667  12.00
# MS         13.250000   9.75

# %%
df2.pivot_table(index=['school'],
                columns=['sex', 'studytime'],
                values=['G3'],
                fill_value=0,
                aggfunc='sum')    # sumando
# Out:
#             G3
# sex          F                    M
# studytime    1     2    3    4    1     2    3    4
# school
# GP         510  1613  717  242  862  1010  246  120
# MS         486   802  267   56  441   263   53   39

# %%
df2.pivot_table(index=['school'],
                columns=['sex', 'studytime'],
                values=['G3'],
                fill_value=0,
                aggfunc='count')   # contando
# Out:
#            G3
# sex         F                M
# studytime   1    2   3   4   1   2   3   4
# school
# GP         42  125  53  17  77  81  18  10
# MS         47   73  22   4  46  26   4   4

# %% [markdown]
# ### Aplicación de funciones

# %% [markdown]
# ### Json Normalize, Explode

# %% [markdown]
# ### Unión de dataframes

# %% [markdown]
# ### Eval y query

# %% [markdown]
# ### lookup

# %% [markdown]
# ### index y reindex

# %% [markdown]
# ### Multi index

# %% [markdown]
# ### Exportar datos

# %% [markdown]
# ### Métodos habituales de pandas

# %% [markdown]
# ```python
# df.head()                     # printea la cabeza, por defecto 5 filas
# df.tail()                     # pritea la cola, por defecto 5 filas
# df.describe()                 # descripcion estadistica
# df.info()                     # informacion del df
# df.info(memory_usage='deep')
# df.columns                    # muestra columna
# df.index                      # muestra indice
# df.dtypes                     # muestra tipos de datos de las columnas
# df.plot()                     # hace un grafico
# df.hist()                     # hace un histograma
# df.col.value_counts()         # cuenta los valores unicos de una columna
# df.col.unique()               # muestra valores unicos de una columna
# df.copy()                     # copia el df
# df.drop()                     # elimina columnas o filas (axis=0,1)
# df.dropna()                   # elimina nulos
# df.fillna()                   # rellena nulos
# df.shape                      # dimensiones del df
# df._get_numeric_data()        # selecciona columnas numericas
# df.rename()                   # renombre columnas
# df.str.replace()              # reemplaza columnas de strings
# df.astype(dtype='float32')    # cambia el tipo de dato
# df.iloc[]                     # localiza por indice
# df.loc[]                      # localiza por elemento
# df.ix[]                       # loc+iloc
# df.transpose()                # transpone el df
# df.T
# df.sample(n, frac)            # muestra del df
# df.col.sum()                  # suma de una columna
# df.col.max()                  # maximo de una columna
# df.col.min()                  # minimo de una columna
# df[col]                       # selecciona columna
# df.col
# df.isnull()                   # valores nulos
# df.isna()
# df.notna()                    # valores no nulos
# df.drop_duplicates()          # eliminar duplicados
# df.reset_index(inplace=True)  # resetea el indice y sobreescribe
# ```
