# %%
import pandas as pd

# %%
pd.read_csv('../data/bth_price.csv').shape
# Out:
# (28, 5)

# %%
pd.read_csv('../data/bth_price.csv')
# Out:
#    bitcoin_price bitcoin_price_var bit_eth_price bit_eth_price_var  \
# 0       32840.72             10.44         13.18             10.44
# 1       32845.68              10.3         13.21              10.3
# 2       32845.68              10.3         13.21              10.3
# 3       32845.68              10.3         13.21              10.3
# 4       32845.68              10.3         13.21              10.3
# 5       32845.68              10.3         13.21              10.3
# 6       32845.68              10.3         13.21              10.3
# 7       31830.83              11.8         13.22              11.8
# 8       31830.83              11.8         13.22              11.8
# 9       31916.64             11.59         13.29             11.59
# 10      31916.64             11.59         13.29             11.59
# 11       31935.5             11.45         13.34             11.45
# 12       31935.5             11.45         13.34             11.45
# ...
